# %%
# matlotlib inline plotting
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import tensorflow as tf
import numpy as np
from six.moves import cPickle as pickle
from scipy import ndimage

# %% [markdown]
# # Load data

# %%
try:
    with open('tensorflow_ready_data.pickle', 'rb') as f:
        dataset = pickle.load(f)
        train_dataset = dataset['train']['data'].reshape(-1, 32, 32, 1)
        test_dataset = dataset['test']['data'].reshape(-1, 32, 32, 1)
        validation_dataset = dataset['valid']['data'].reshape(-1, 32, 32, 1)
        extra_dataset = dataset['extra']['data'].reshape(-1, 32, 32, 1)
        train_labels = dataset['train']['label']
        test_labels = dataset['test']['label']
        validation_labels = dataset['valid']['label']
        extra_labels = dataset['extra']['label']

except Exception as e:
    print('Unable to load data to',  'tensorflow_ready_data.pickle' + '.pickle', ':', e)
    raise

# %% [markdown]
# # Model
#
# We have setup the model up as foolows:
# - 7-layer CNN.
# - C1: convolutional layer, batch_size x 28 x 28 x 16, convolution size: 5 x 5 x 1 x 16
# - S2: sub-sampling layer, batch_size x 14 x 14 x 16
# - C3: convolutional layer, batch_size x 10 x 10 x 32, convolution size: 5 x 5 x 16 x 32
# - S4: sub-sampling layer, batch_size x 5 x 5 x 32
# - C5: convolutional layer, batch_size x 1 x 1 x 64, convolution size: 5 x 5 x 32 x 64
# - Dropout F6: fully-connected layer, weight size: 64 x 16
# - Output layer, weight size: 16 x 10

# %%
def accuracy(predictions, labels):
    return (100.0 * np.sum(np.argmax(predictions, 2).T == labels) / predictions.shape[1] / predictions.shape[0])

image_size = 32
num_labels = 11 # digits 0-9, + blank 
num_channels = 1

batch_size = 64
patch_size = 5

depth1 = 16
depth2 = 32
depth3 = 64

num_hidden1 = 64
#num_hidden2 = 16

shape = [batch_size, image_size, image_size, num_channels]

num_steps = 30000

# %%
graph = tf.Graph()

# %%
with graph.as_default():
    # Input data.
    tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.int32, shape=(batch_size, 6))
    tf_valid_dataset = tf.constant(validation_dataset)
    tf_test_dataset = tf.constant(test_dataset)

    # Variables.
    layer1_weights = tf.get_variable("W1", shape=[patch_size, patch_size, num_channels, depth1],\
           initializer=tf.contrib.layers.xavier_initializer_conv2d())
    layer1_biases = tf.Variable(tf.constant(1.0, shape=[depth1]), name='B1')
    
    layer2_weights = tf.get_variable("W2", shape=[patch_size, patch_size, depth1, depth2],\
           initializer=tf.contrib.layers.xavier_initializer_conv2d())
    layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth2]), name='B2')
    
    layer3_weights = tf.get_variable("W3", shape=[patch_size, patch_size, depth2, num_hidden1],\
           initializer=tf.contrib.layers.xavier_initializer_conv2d())
    layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden1]), name='B3')

    s1_w = tf.get_variable("WS1", shape=[num_hidden1, num_labels],\
           initializer=tf.contrib.layers.xavier_initializer())
    s1_b = tf.Variable(tf.constant(1.0, shape=[num_labels]), name='BS1')
    
    s2_w = tf.get_variable("WS2", shape=[num_hidden1, num_labels],\
           initializer=tf.contrib.layers.xavier_initializer())
    s2_b = tf.Variable(tf.constant(1.0, shape=[num_labels]), name='BS2')
    
    s3_w = tf.get_variable("WS3", shape=[num_hidden1, num_labels],\
           initializer=tf.contrib.layers.xavier_initializer())
    s3_b = tf.Variable(tf.constant(1.0, shape=[num_labels]), name='BS3')
    
    s4_w = tf.get_variable("WS4", shape=[num_hidden1, num_labels],\
           initializer=tf.contrib.layers.xavier_initializer())
    s4_b = tf.Variable(tf.constant(1.0, shape=[num_labels]), name='BS4')
    
    s5_w = tf.get_variable("WS5", shape=[num_hidden1, num_labels],\
           initializer=tf.contrib.layers.xavier_initializer())
    s5_b = tf.Variable(tf.constant(1.0, shape=[num_labels]), name='BS5')
  

    def model(data, keep_prob, shape):
        conv = tf.nn.conv2d(data,layer1_weights, [1,1,1,1],padding='VALID', name='C1')
        hidden = tf.nn.relu(conv + layer1_biases)
        lrn = tf.nn.local_response_normalization(hidden)
        sub = tf.nn.max_pool(lrn, [1,2,2,1], [1,2,2,1], 'SAME', name='S2')
        conv = tf.nn.conv2d(sub, layer2_weights, [1,1,1,1], padding='VALID', name='C3')
        hidden = tf.nn.relu(conv + layer2_biases)
        lrn = tf.nn.local_response_normalization(hidden)
        sub = tf.nn.max_pool(lrn, [1,2,2,1], [1,2,2,1], 'SAME', name='S4')
        conv = tf.nn.conv2d(sub, layer3_weights, [1,1,1,1], padding='VALID', name='C5')
        hidden = tf.nn.relu(conv + layer3_biases)
        hidden = tf.nn.dropout(hidden, keep_prob)
        shape = hidden.get_shape().as_list()
        reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])

        logits1 = tf.matmul(reshape, s1_w) + s1_b
        logits2 = tf.matmul(reshape, s2_w) + s2_b
        logits3 = tf.matmul(reshape, s3_w) + s3_b
        logits4 = tf.matmul(reshape, s4_w) + s4_b
        logits5 = tf.matmul(reshape, s5_w) + s5_b
        return [logits1, logits2, logits3, logits4, logits5]
  
    # Training computation.
    [logits1, logits2, logits3, logits4, logits5] = model(tf_train_dataset, 0.9375, shape)
    
    # Define loss function.
    loss = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(logits=logits1, labels=tf_train_labels[:,1])) +\
           tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(logits=logits2, labels=tf_train_labels[:,2])) +\
           tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(logits=logits3, labels=tf_train_labels[:,3])) +\
           tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(logits=logits4, labels=tf_train_labels[:,4])) +\
           tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(logits=logits5, labels=tf_train_labels[:,5]))
    
    # Optimizer.
    global_step = tf.Variable(0)
    
    #learning rate with exponential decay.
    learning_rate = tf.train.exponential_decay(0.05, global_step, 10000, 0.95) 
    optimizer = tf.train.AdagradOptimizer(learning_rate).minimize(loss, global_step=global_step)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.stack([tf.nn.softmax(model(tf_train_dataset, 1.0, shape)[0]),\
                      tf.nn.softmax(model(tf_train_dataset, 1.0, shape)[1]),\
                      tf.nn.softmax(model(tf_train_dataset, 1.0, shape)[2]),\
                      tf.nn.softmax(model(tf_train_dataset, 1.0, shape)[3]),\
                      tf.nn.softmax(model(tf_train_dataset, 1.0, shape)[4])])
    
    valid_prediction = tf.stack([tf.nn.softmax(model(tf_valid_dataset, 1.0, shape)[0]),\
                      tf.nn.softmax(model(tf_valid_dataset, 1.0, shape)[1]),\
                      tf.nn.softmax(model(tf_valid_dataset, 1.0, shape)[2]),\
                      tf.nn.softmax(model(tf_valid_dataset, 1.0, shape)[3]),\
                      tf.nn.softmax(model(tf_valid_dataset, 1.0, shape)[4])])
    
    test_prediction = tf.stack([tf.nn.softmax(model(tf_test_dataset, 1.0, shape)[0]),\
                     tf.nn.softmax(model(tf_test_dataset, 1.0, shape)[1]),\
                     tf.nn.softmax(model(tf_test_dataset, 1.0, shape)[2]),\
                     tf.nn.softmax(model(tf_test_dataset, 1.0, shape)[3]),\
                     tf.nn.softmax(model(tf_test_dataset, 1.0, shape)[4])])
    
    saver = tf.train.Saver()

# %%
with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()

  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size),:]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    
    if (step % 500 == 0): 
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels[:,1:6]))
      print('Validation accuracy: %.1f%%' % accuracy(valid_prediction.eval(), validation_labels[:,1:6]))
  

  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels[:,1:6]))
  save_path = saver.save(session, "SVHN_MODEL.ckpt")
  print("Model saved in file: %s" % save_path)
# Out:
# Initialized
# Minibatch loss at step 0: 14.266173
# Minibatch accuracy: 1.6%
# Validation accuracy: 69.8%
# Minibatch loss at step 500: 3.374985
# Minibatch accuracy: 82.2%
# Validation accuracy: 71.7%
# Minibatch loss at step 1000: 3.652033
# Minibatch accuracy: 78.4%
# Validation accuracy: 71.7%
# Minibatch loss at step 1500: 3.155852
# Minibatch accuracy: 80.3%
# Validation accuracy: 71.7%
# Minibatch loss at step 2000: 3.753230
# Minibatch accuracy: 77.8%
# Validation accuracy: 71.6%
# Minibatch loss at step 2500: 3.455150
# Minibatch accuracy: 79.1%
# Validation accuracy: 71.4%
# Minibatch loss at step 3000: 3.048218
# Minibatch accuracy: 80.0%
# Validation accuracy: 71.7%
# Minibatch loss at step 3500: 3.445880
# Minibatch accuracy: 78.1%
# Validation accuracy: 71.8%
# Minibatch loss at step 4000: 3.193502
# Minibatch accuracy: 80.0%
# Validation accuracy: 71.9%
# Minibatch loss at step 4500: 2.965761
# Minibatch accuracy: 81.6%
# Validation accuracy: 71.8%
# Minibatch loss at step 5000: 3.221515
# Minibatch accuracy: 79.1%
# Validation accuracy: 72.0%
# Minibatch loss at step 5500: 3.105682
# Minibatch accuracy: 79.4%
# Validation accuracy: 72.0%
# Minibatch loss at step 6000: 2.729978
# Minibatch accuracy: 80.6%
# Validation accuracy: 72.0%
# Minibatch loss at step 6500: 2.836347
# Minibatch accuracy: 81.2%
# Validation accuracy: 72.4%
# Minibatch loss at step 7000: 2.613262
# Minibatch accuracy: 80.6%
# Validation accuracy: 72.4%
# Minibatch loss at step 7500: 2.300942
# Minibatch accuracy: 86.6%
# Validation accuracy: 72.6%
# Minibatch loss at step 8000: 2.435059
# Minibatch accuracy: 84.4%
# Validation accuracy: 72.5%
# Minibatch loss at step 8500: 2.991117
# Minibatch accuracy: 83.8%
# Validation accuracy: 72.7%
# Minibatch loss at step 9000: 2.321649
# Minibatch accuracy: 85.6%
# Validation accuracy: 72.8%
# Minibatch loss at step 9500: 2.008354
# Minibatch accuracy: 86.9%
# Validation accuracy: 73.1%
# Minibatch loss at step 10000: 2.376117
# Minibatch accuracy: 85.0%
# Validation accuracy: 73.3%
# Minibatch loss at step 10500: 1.822379
# Minibatch accuracy: 88.1%
# Validation accuracy: 73.2%
# Minibatch loss at step 11000: 2.419779
# Minibatch accuracy: 84.7%
# Validation accuracy: 73.5%
# Minibatch loss at step 11500: 2.479889
# Minibatch accuracy: 85.3%
# Validation accuracy: 73.4%
# Minibatch loss at step 12000: 2.922898
# Minibatch accuracy: 82.5%
# Validation accuracy: 73.5%
# Minibatch loss at step 12500: 2.145452
# Minibatch accuracy: 86.2%
# Validation accuracy: 73.5%
# Minibatch loss at step 13000: 2.268440
# Minibatch accuracy: 86.2%
# Validation accuracy: 73.6%
# Minibatch loss at step 13500: 1.940840
# Minibatch accuracy: 87.5%
# Validation accuracy: 73.7%
# Minibatch loss at step 14000: 2.281284
# Minibatch accuracy: 84.7%
# Validation accuracy: 73.9%
# Minibatch loss at step 14500: 1.585437
# Minibatch accuracy: 89.4%
# Validation accuracy: 73.7%
# Minibatch loss at step 15000: 2.490726
# Minibatch accuracy: 83.4%
# Validation accuracy: 74.0%
# Minibatch loss at step 15500: 2.115546
# Minibatch accuracy: 87.2%
# Validation accuracy: 73.9%
# Minibatch loss at step 16000: 1.911740
# Minibatch accuracy: 89.7%
# Validation accuracy: 74.1%
# Minibatch loss at step 16500: 1.939648
# Minibatch accuracy: 87.5%
# Validation accuracy: 74.3%
# Minibatch loss at step 17000: 1.568057
# Minibatch accuracy: 90.9%
# Validation accuracy: 74.2%
# Minibatch loss at step 17500: 2.137110
# Minibatch accuracy: 87.2%
# Validation accuracy: 74.3%
# Minibatch loss at step 18000: 1.980900
# Minibatch accuracy: 88.1%
# Validation accuracy: 74.5%
# Minibatch loss at step 18500: 2.026448
# Minibatch accuracy: 87.5%
# Validation accuracy: 74.2%
# Minibatch loss at step 19000: 1.798524
# Minibatch accuracy: 87.5%
# Validation accuracy: 74.4%
# Minibatch loss at step 19500: 1.453433
# Minibatch accuracy: 92.2%
# Validation accuracy: 74.3%
# Minibatch loss at step 20000: 1.850886
# Minibatch accuracy: 90.0%
# Validation accuracy: 74.8%
# Minibatch loss at step 20500: 1.993749
# Minibatch accuracy: 87.5%
# Validation accuracy: 74.6%
# Minibatch loss at step 21000: 1.940366
# Minibatch accuracy: 88.8%
# Validation accuracy: 74.7%
# Minibatch loss at step 21500: 2.241108
# Minibatch accuracy: 86.9%
# Validation accuracy: 74.8%
# Minibatch loss at step 22000: 1.882799
# Minibatch accuracy: 88.8%
# Validation accuracy: 74.6%
# Minibatch loss at step 22500: 1.350345
# Minibatch accuracy: 92.5%
# Validation accuracy: 74.8%
# Minibatch loss at step 23000: 2.481936
# Minibatch accuracy: 83.4%
# Validation accuracy: 74.3%
# Minibatch loss at step 23500: 1.869658
# Minibatch accuracy: 89.4%
# Validation accuracy: 74.7%
# Minibatch loss at step 24000: 1.651934
# Minibatch accuracy: 89.1%
# Validation accuracy: 74.4%
# Minibatch loss at step 24500: 1.612291
# Minibatch accuracy: 90.9%
# Validation accuracy: 74.6%
# Minibatch loss at step 25000: 1.464114
# Minibatch accuracy: 90.3%
# Validation accuracy: 75.0%
# Minibatch loss at step 25500: 2.042146
# Minibatch accuracy: 89.1%
# Validation accuracy: 74.7%
# Minibatch loss at step 26000: 1.615939
# Minibatch accuracy: 90.3%
# Validation accuracy: 75.0%
# Minibatch loss at step 26500: 2.138393
# Minibatch accuracy: 88.1%
# Validation accuracy: 74.8%
# Minibatch loss at step 27000: 1.543697
# Minibatch accuracy: 90.3%
# Validation accuracy: 74.8%
# Minibatch loss at step 27500: 1.689218
# Minibatch accuracy: 88.4%
# Validation accuracy: 75.0%
# Minibatch loss at step 28000: 1.620741
# Minibatch accuracy: 90.6%
# Validation accuracy: 75.0%
# Minibatch loss at step 28500: 2.234847
# Minibatch accuracy: 86.2%
# Validation accuracy: 74.9%
# Minibatch loss at step 29000: 1.630022
# Minibatch accuracy: 90.6%
# Validation accuracy: 74.8%
# Minibatch loss at step 29500: 0.998828
# Minibatch accuracy: 94.7%
# Validation accuracy: 74.9%
# Test accuracy: 85.7%
# Model saved in file: SVHN_MODEL.ckpt
